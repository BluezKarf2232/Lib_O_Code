# %%
import pandas as pd
from konlpy.utils import pprint
korean_review_df=pd.read_csv("D:\\edu_pythonADV\\nsmc-master\\ratings_test.txt",header=0,delimiter='\t',quoting=3,encoding='utf-8')
len(korean_review_df)
#print(korean_review_df[:5])

from konlpy.tag import Okt
twi_tagger=Okt()

temp_sen=u'마늘치킨이 먹고싶닼ㅋㅋ 치킨 사랑해~'
pprint(twi_tagger.pos(temp_sen,norm=True,stem=True))
# Out:
# [('마늘', 'Noun'),
#  ('치킨', 'Noun'),
#  ('이', 'Josa'),
#  ('먹다', 'Verb'),
#  ('ㅋㅋ', 'KoreanParticle'),
#  ('치킨', 'Noun'),
#  ('사랑', 'Noun'),
#  ('하다', 'Verb'),
#  ('~', 'Punctuation')]

# %%
words_temp=twi_tagger.pos(korean_review_df['document'][3],norm=True,stem=True)
pprint(words_temp)

# %%
import nltk
tokenizer=nltk.data.load('tokenizers/punkt/english.pickle')
tokenizer

# %%
from bs4 import BeautifulSoup
import re
from nltk.corpus import stopwords
def tokenizer_twit(doc):
    return ['/'.join(t) for t in twi_tagger.pos(doc,norm=True,stem=True)]
def review_to_wordlist(review):
    try:
        review_text=BeautifulSoup(review.strip()).get_text()
    except AttributeError as e:
        print(e)
        review_text=""
    review_words=tokenizer_twit(review_text)
    return review_words
words=[]
review_num=0
for review in korean_review_df['documents']:
    words+=review_to_wordlist(review)
    review_num+=1
    if review_num%5000==0:
        print('review_num : ',review_num)

# %%
import pandas as pd
from konlpy.utils import pprint
korean_review_df=pd.read_csv("D:\\edu_pythonADV\\nsmc-master\\ratings_test.txt",header=0,delimiter='\t',quoting=3,encoding='utf-8')
len(korean_review_df)
#print(korean_review_df[:5])

from konlpy.tag import Okt
twi_tagger=Okt()

#temp_sen=u'마늘치킨이 먹고싶닼ㅋㅋ 치킨 사랑해~'
#pprint(twi_tagger.pos(temp_sen,norm=True,stem=True))

words_temp=twi_tagger.pos(korean_review_df['document'][3],norm=True,stem=True)
pprint(words_temp)

import nltk
tokenizer=nltk.data.load('tokenizers/punkt/english.pickle')
tokenizer

from bs4 import BeautifulSoup
import re
from nltk.corpus import stopwords
def tokenizer_twit(doc):
    return ['/'.join(t) for t in twi_tagger.pos(doc,norm=True,stem=True)]
def review_to_wordlist(review):
    try:
        review_text=BeautifulSoup(review.strip()).get_text()
    except AttributeError as e:
        print(e)
        review_text=""
    review_words=tokenizer_twit(review_text)
    return review_words
words=[]
review_num=0
for review in korean_review_df['document']:
    words+=review_to_wordlist(review)
    review_num+=1
    if review_num%5000==0:
        print('review_num : ',review_num)

len(words)
pprint(words[:10])
import nltk
words_nltk=nltk.Text(words,name='words in movie reviews')
pprint(words_nltk.vocab().most_common(10))
import matplotlib
matplotlib.rc('font',family='HYnamM')
# %matplotlib inline
#words_nltk.plot(40)
print('불용어 처리 가즈아!')
Non_Stop_words=['Noun','Verb','Adjective','Adverb','Exclamation','KoreanParticle']
words_new=[w for w in words if w.split('/')[-1] in Non_Stop_words]
pprint(words_new[:10])
words_nltk_new=nltk.Text(words_new,name='new words in movie reviews')
pprint(words_nltk_new.vocab().most_common(10))
words_nltk_new.plot(40)
# Out:
# [('지루하다', 'Adjective'),
#  ('않다', 'Verb'),
#  ('완전', 'Noun'),
#  ('막장', 'Noun'),
#  ('임', 'Noun'),
#  ('...', 'Punctuation'),
#  ('돈', 'Noun'),
#  ('주다', 'Verb'),
#  ('보기', 'Noun'),
#  ('에는', 'Josa'),
#  ('....', 'Punctuation')]
# c:\users\1\appdata\local\programs\python\python36\lib\site-packages\bs4\__init__.py:302: UserWarning: "b'.'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# c:\users\1\appdata\local\programs\python\python36\lib\site-packages\bs4\__init__.py:302: UserWarning: "b'...'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# review_num :  5000
# 'float' object has no attribute 'strip'
# c:\users\1\appdata\local\programs\python\python36\lib\site-packages\bs4\__init__.py:302: UserWarning: "b'..........'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# 'float' object has no attribute 'strip'
# c:\users\1\appdata\local\programs\python\python36\lib\site-packages\bs4\__init__.py:302: UserWarning: "b'.....'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# review_num :  10000
# c:\users\1\appdata\local\programs\python\python36\lib\site-packages\bs4\__init__.py:302: UserWarning: "b'..............'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# c:\users\1\appdata\local\programs\python\python36\lib\site-packages\bs4\__init__.py:302: UserWarning: "b'....'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# review_num :  15000
# c:\users\1\appdata\local\programs\python\python36\lib\site-packages\bs4\__init__.py:302: UserWarning: "b'..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# review_num :  20000
# c:\users\1\appdata\local\programs\python\python36\lib\site-packages\bs4\__init__.py:302: UserWarning: "b'\xec\xa7\x90\xec\xbc\x80\xeb\xa6\xac\xeb\x8f\x84 \xec\x9d\xb4\xec\xa0\xa0,,//..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# c:\users\1\appdata\local\programs\python\python36\lib\site-packages\bs4\__init__.py:302: UserWarning: "b'.............'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# review_num :  25000
# 'float' object has no attribute 'strip'
# review_num :  30000
# review_num :  35000
# review_num :  40000
# review_num :  45000
# c:\users\1\appdata\local\programs\python\python36\lib\site-packages\bs4\__init__.py:302: UserWarning: "b'\xeb\xad\x90\xec\xa7\x80 \xec\x9d\xb4\xec\x98\x81\xed\x99\x94\xeb\x8a\x94.../..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# review_num :  50000
# ['굳다/Adjective',
#  'ㅋ/KoreanParticle',
#  'GDNTOPCLASSINTHECLUB/Alpha',
#  '뭐/Noun',
#  '야/Josa',
#  '이/Noun',
#  '평점/Noun',
#  '들/Suffix',
#  '은/Josa',
#  '..../Punctuation']
# [('./Punctuation', 22622),
#  ('영화/Noun', 17324),
#  ('하다/Verb', 13747),
#  ('이/Josa', 13103),
#  ('보다/Verb', 12838),
#  ('의/Josa', 10142),
#  ('../Punctuation', 9588),
#  ('에/Josa', 9043),
#  ('가/Josa', 8892),
#  ('.../Punctuation', 7715)]
# ['굳다/Adjective',
#  'ㅋ/KoreanParticle',
#  '뭐/Noun',
#  '이/Noun',
#  '평점/Noun',
#  '나쁘다/Adjective',
#  '않다/Verb',
#  '점/Noun',
#  '짜다/Verb',
#  '리/Noun']
# [('영화/Noun', 17324),
#  ('하다/Verb', 13747),
#  ('보다/Verb', 12838),
#  ('없다/Adjective', 5319),
#  ('있다/Adjective', 4146),
#  ('좋다/Adjective', 4033),
#  ('너무/Adverb', 3735),
#  ('재밌다/Adjective', 3489),
#  ('정말/Noun', 3199),
#  ('것/Noun', 3176)]

# %%
import matplotlib.font_manager as fm
font_list=fm.findSystemFonts(fontpaths=None,fontext='ttf')
f=[f.name for f in fm.fontManager.ttflist]
f
# Out:
# ['DejaVu Sans Display',
#  'STIXNonUnicode',
#  'DejaVu Serif',
#  'cmr10',
#  'DejaVu Sans Mono',
#  'STIXSizeThreeSym',
#  'STIXSizeTwoSym',
#  'DejaVu Sans Mono',
#  'cmsy10',
#  'STIXSizeFourSym',
#  'cmtt10',
#  'STIXNonUnicode',
#  'DejaVu Serif',
#  'STIXNonUnicode',
#  'STIXSizeOneSym',
#  'cmmi10',
#  'DejaVu Serif Display',
#  'cmb10',
#  'STIXGeneral',
#  'STIXGeneral',
#  'STIXSizeThreeSym',
#  'DejaVu Serif',
#  'DejaVu Sans Mono',
#  'STIXGeneral',
#  'STIXNonUnicode',
#  'STIXSizeFourSym',
#  'cmss10',
#  'DejaVu Sans',
#  'DejaVu Sans',
#  'DejaVu Sans',
#  'DejaVu Serif',
#  'STIXSizeFiveSym',
#  'cmex10',
#  'DejaVu Sans Mono',
#  'STIXGeneral',
#  'DejaVu Sans',
#  'STIXSizeOneSym',
#  'STIXSizeTwoSym',
#  'HYgtrE',
#  'HYbsrB',
#  'MDEasop',
#  'Californian FB',
#  'Haan Sollip M',
#  'Bodoni MT',
#  'Arial',
#  'Poor Richard',
#  '??????',
#  'Rage Italic',
#  'Rockwell Extra Bold',
#  'Ebrima',
#  'Tw Cen MT Condensed',
#  'Bodoni MT',
#  'Yj BONMOKGAK Medium ',
#  'Bell MT',
#  'Segoe Print',
#  'Bodoni Bd BT',
#  'Haan Sale M',
#  'Verdana',
#  'Wide Latin',
#  'Pyunji R',
#  'Perpetua Titling MT',
#  'Georgia',
#  'Copperplate Gothic Bold',
#  'Microsoft New Tai Lue',
#  '??????',
#  'Lucida Handwriting',
#  'Arial',
#  'Matura MT Script Capitals',
#  'Goudy Old Style',
#  'Franklin Gothic Medium',
#  'HCR Batang',
#  'Tw Cen MT Condensed',
#  'MSugiJeong',
#  'Century Gothic',
#  'Trebuchet MS',
#  'MGungJeong',
#  'Eras Bold ITC',
#  'Rockwell Condensed',
#  'HYgprM',
#  'HYbdaL',
#  'Hobo BT',
#  'HYnamM',
#  'Garamond',
#  'Showcard Gothic',
#  'Tw Cen MT',
#  'Playbill',
#  'Kunstler Script',
#  'Malgun Gothic',
#  'Harlow Solid Italic',
#  'Segoe UI Emoji',
#  'Gill Sans Ultra Bold Condensed',
#  'HYkanB',
#  'Swis721 BT',
#  'Constantia',
#  'HYMyeongJo-Extra',
#  'Edwardian Script ITC',
#  'Nirmala UI',
#  'Bodoni MT',
#  'Haan Baekje B',
#  'Rockwell',
#  'Gill Sans MT',
#  'Arial',
#  'Segoe MDL2 Assets',
#  'Vivaldi',
#  'HYGraphic-Medium',
#  'Haan Cooljazz L',
#  'Franklin Gothic Heavy',
#  'Constantia',
#  'Segoe UI',
#  'Segoe UI',
#  '??????',
#  'Microsoft YaHei',
#  'Constantia',
#  'OCR-B-10 BT',
#  'Gill Sans Ultra Bold',
#  'MT Extra',
#  'Times New Roman',
#  'Candara',
#  'Leelawadee UI',
#  'Haan Sollip B',
#  'Monotype Corsiva',
#  'Corbel',
#  'HCR Dotum',
#  'Verdana',
#  'Malgun Gothic',
#  'Gabriola',
#  'Brush Script MT',
#  'Mistral',
#  'MJemokBatang',
#  'Segoe UI',
#  'Franklin Gothic Heavy',
#  'MJemokGothic',
#  'Footlight MT Light',
#  'Freestyle Script',
#  'Vladimir Script',
#  'Haan Baekje M',
#  'HYkanM',
#  'Haan YHead B',
#  'Berlin Sans FB Demi',
#  'HCR Dotum Ext',
#  'MDGaesung',
#  'Cooper Blk BT',
#  'Consolas',
#  'Segoe UI Historic',
#  'Tahoma',
#  'Corbel',
#  'Gadugi',
#  'Leelawadee UI',
#  'Ebrima',
#  'MS Mincho',
#  'ahn2006-B',
#  'Onyx',
#  'HYsupM',
#  'Lucida Sans Typewriter',
#  'Bauhaus 93',
#  'HYSinMyeongJo-Medium',
#  'Orbit-B BT',
#  'Sitka Small',
#  'GoudyOlSt BT',
#  'Leelawadee UI',
#  'Yj CHMSOOT Bold',
#  'MDotum',
#  'Tw Cen MT',
#  'Myanmar Text',
#  'Haan YHead M',
#  'French Script MT',
#  'Pristina',
#  'Georgia',
#  'HYdnkB',
#  'Microsoft YaHei',
#  'Segoe UI',
#  'Bodoni MT',
#  'Bookshelf Symbol 7',
#  'Bell MT',
#  'Lucida Sans Typewriter',
#  'Consolas',
#  'Cooper Blk BT',
#  'HYShortSamul-Medium',
#  'Javanese Text',
#  'HP Simplified',
#  'GoudyOlSt BT',
#  'Batang',
#  'Segoe UI',
#  'GoudyOlSt BT',
#  'Perpetua',
#  'HYGothic-Extra',
#  'Yj BACDOO Bold ',
#  'MS Reference Specialty',
#  'Arial',
#  'Century Gothic',
#  'Arial',
#  'SimSun-ExtB',
#  'MDArt',
#  'Algerian',
#  'Magneto',
#  'Sylfaen',
#  'HoloLens MDL2 Assets',
#  'ahn2006-M',
#  'Eras Demi ITC',
#  'Courier New',
#  'HP Simplified',
#  'Ami R',
#  'Lucida Bright',
#  'Palatino Linotype',
#  'ahn2006-L',
#  'Orator10 BT',
#  'Meiryo',
#  'Papyrus',
#  'HCR Dotum',
#  'Verdana',
#  'Calisto MT',
#  'Century Gothic',
#  'Modern No. 20',
#  'Sitka Small',
#  'Bernard MT Condensed',
#  'Consolas',
#  'Bahnschrift',
#  'HYdnkM',
#  'Haan Cooljazz M',
#  'HYmjrE',
#  'Cooper Black',
#  'Gigi',
#  'Rockwell',
#  'Tempus Sans ITC',
#  'HYnamB',
#  'Arial',
#  'Cambria',
#  'Calibri',
#  'Courier New',
#  'Microsoft YaHei',
#  'Yj DWMMOOGJO',
#  'Segoe UI',
#  'HCR Batang',
#  'ParkAvenue BT',
#  'Berlin Sans FB',
#  'Goudy Old Style',
#  'HP Simplified',
#  'Yu Gothic',
#  '????',
#  'Eras Light ITC',
#  'Lucida Bright',
#  'Perpetua',
#  'Lucida Sans',
#  'Californian FB',
#  'Gill Sans MT Condensed',
#  'Ink Free',
#  'HYwulB',
#  'Wingdings 3',
#  'Segoe Script',
#  '??????',
#  'Impact',
#  'Rockwell Condensed',
#  'Sitka Small',
#  'Corbel',
#  'Haan Somang B',
#  'Yj MAEHWA  SemiBold',
#  'Niagara Solid',
#  'HCR Batang Ext',
#  'Century Gothic',
#  'HYsanB',
#  'Headline R',
#  'Meiryo',
#  'GoudyOlSt BT',
#  'Bookman Old Style',
#  'Colonna MT',
#  'Yj WADAG Medium',
#  'Arial',
#  'Century',
#  'Microsoft Himalaya',
#  'CentSchbook BT',
#  'Agency FB',
#  'Arial',
#  'High Tower Text',
#  'HYporM',
#  'Yj GOTGAE Medium',
#  'Franklin Gothic Medium Cond',
#  'Kristen ITC',
#  'Century Schoolbook',
#  'Calisto MT',
#  'Courier10 BT',
#  '? ??',
#  'Rockwell',
#  'Berlin Sans FB',
#  'Agency FB',
#  'Gill Sans MT',
#  'High Tower Text',
#  'MS Outlook',
#  'Perpetua',
#  'Gill Sans MT',
#  'Microsoft Tai Le',
#  'MDAlong',
#  'Comic Sans MS',
#  'Calibri',
#  'HYbdaM',
#  'Goudy Stout',
#  'HYPost-Light',
#  '??????',
#  'Gloucester MT Extra Condensed',
#  '???',
#  'HP Simplified',
#  'Tw Cen MT Condensed Extra Bold',
#  'Segoe Script',
#  'Haan YGodic 230',
#  'Bookman Old Style',
#  'AmeriGarmnd BT',
#  'Bodoni MT',
#  'MingLiU-ExtB',
#  'Copperplate Gothic Light',
#  'Forte',
#  'Bodoni MT',
#  'Lucida Sans',
#  'Yj GABI',
#  'Yu Gothic',
#  'Broadway',
#  'Nirmala UI',
#  'Bodoni MT',
#  'Malgun Gothic',
#  'Calibri',
#  'BernhardFashion BT',
#  'Liberty BT',
#  'MS Reference Sans Serif',
#  'Haan YGodic 240',
#  'Microsoft Sans Serif',
#  'Arial Rounded MT Bold',
#  'Candara',
#  'Bodoni MT',
#  'Old English Text MT',
#  'Viner Hand ITC',
#  'Comic Sans MS',
#  'HYGothic-Medium',
#  'Nirmala UI',
#  'Century Schoolbook',
#  'Perpetua',
#  'Lucida Calligraphy',
#  'Segoe UI',
#  'Trebuchet MS',
#  'Candara',
#  'Goudy Old Style',
#  'FZSong_Superfont',
#  'Jokerman',
#  '??????',
#  'HYnamL',
#  'Courier New',
#  'Elephant',
#  'Juice ITC',
#  '????',
#  'Curlz MT',
#  'Franklin Gothic Medium',
#  'Californian FB',
#  'YJ INJANG Medium',
#  'Corbel',
#  'HYwulM',
#  'Lucida Fax',
#  'CentSchbook BT',
#  'Lucida Console',
#  'MSugiHeulim',
#  'FuturaBlack BT',
#  'SimSun',
#  'CentSchbook BT',
#  'Bodoni Bd BT',
#  'Microsoft New Tai Lue',
#  'Franklin Gothic Book',
#  'HYtbrB',
#  'Newtext Bk BT',
#  'Harrington',
#  'Rockwell',
#  'Segoe UI',
#  'OCR A Extended',
#  'MurrayHill Bd BT',
#  'Verdana',
#  '??????',
#  'Baskerville Old Face',
#  'Cambria',
#  'Segoe UI',
#  'Perpetua Titling MT',
#  'Arial',
#  'Yj BLOCK Medium',
#  'Yj BUTGOT Light ',
#  'Microsoft JhengHei',
#  'Gadugi',
#  'Gill Sans MT Ext Condensed Bold',
#  'Maiandra GD',
#  'BroadwayEngraved BT',
#  'Script MT Bold',
#  'Haan Cooljazz B',
#  'Corbel',
#  'Lucida Sans Typewriter',
#  'Imprint MT Shadow',
#  'Baskerville BT',
#  'AmeriGarmnd BT',
#  'MHunmin',
#  'Candara',
#  'Arial Unicode MS',
#  'Microsoft Tai Le',
#  'HYsupB',
#  'Book Antiqua',
#  'Comic Sans MS',
#  'Times New Roman',
#  'HYsnrL',
#  'Chiller',
#  'Yj SOSEL SemiBold',
#  'Myanmar Text',
#  'Microsoft JhengHei',
#  'Webdings',
#  'Georgia',
#  'HYmprL',
#  'Blackadder ITC',
#  'Yu Gothic',
#  'Bodoni MT',
#  'OCR-A BT',
#  'HYPMokGak-Bold',
#  'Elephant',
#  'Calibri',
#  'Franklin Gothic Book',
#  'Trebuchet MS',
#  'Courier New',
#  'MGungHeulim',
#  'Castellar',
#  'HP Simplified',
#  'Courier10 BT',
#  'Calisto MT',
#  'Constantia',
#  'Segoe Print',
#  'Symbol',
#  'Magic R',
#  'Franklin Gothic Demi Cond',
#  'Lucida Bright',
#  'Haettenschweiler',
#  'Bodoni MT',
#  'Candara',
#  'Segoe UI',
#  'Franklin Gothic Demi',
#  'Sitka Small',
#  'MV Boli',
#  'Bradley Hand ITC',
#  'Franklin Gothic Demi',
#  'Tw Cen MT',
#  'Felix Titling',
#  'CommercialScript BT',
#  'Segoe UI Symbol',
#  'Garamond',
#  'HYgsrB',
#  'Book Antiqua',
#  'Informal Roman',
#  'Calibri',
#  'Parchment',
#  'Calibri',
#  'Wingdings',
#  'Lucida Bright',
#  'Lucida Fax',
#  '??????',
#  'Segoe UI',
#  'MBatang',
#  'Yj SHANALL Medium ',
#  'Engravers MT',
#  'Palatino Linotype',
#  'DomCasual BT',
#  'Book Antiqua',
#  'Consolas',
#  'Snap ITC',
#  'Haansoft Batang',
#  'Ravie',
#  'CentSchbook BT',
#  'Niagara Engraved',
#  'Tw Cen MT',
#  'Blippo Blk BT',
#  'Gulim',
#  'Mongolian Baiti',
#  'Yj TEUNTEUN Bold',
#  'Times New Roman',
#  'Yj INITIALPOSITIVE Medium',
#  'Tera Special',
#  'Georgia',
#  'Century Schoolbook',
#  'Corbel',
#  'YJ BELLA Medium',
#  'Bookman Old Style',
#  'Times New Roman',
#  'Calisto MT',
#  'Haan Somang M',
#  'MDSol',
#  'Bell MT',
#  'Lucida Sans Typewriter',
#  'Haan Sale B',
#  'Lucida Fax',
#  'Lucida Sans',
#  'Yu Gothic',
#  'Tahoma',
#  'Segoe UI',
#  '????',
#  'Microsoft Yi Baiti',
#  'Lucida Fax',
#  'Book Antiqua',
#  'Cambria',
#  'HYPost-Medium',
#  'Microsoft JhengHei',
#  'HyhwpEQ',
#  'Century Schoolbook',
#  'Palace Script MT',
#  'Lucida Sans',
#  'Palatino Linotype',
#  'Stencil',
#  'Freehand591 BT',
#  'Yj DOOLGI Medium',
#  'Haansoft Dotum',
#  'BrushScript BT',
#  '??????',
#  'MS Gothic',
#  'Stencil BT',
#  'Lucida Sans Unicode',
#  'Bodoni Bk BT',
#  'Eras Medium ITC',
#  'Yet R',
#  'Garamond',
#  'Bodoni Bk BT',
#  'Palatino Linotype',
#  'Haan YHead L',
#  'Britannic Bold',
#  'New Gulim',
#  'HYHeadLine M',
#  'HYhaeseo',
#  'Candara',
#  'Yj NANCHO Medium',
#  'Microsoft PhagsPa',
#  'Microsoft PhagsPa',
#  'HP Simplified',
#  'Bodoni MT',
#  'Swis721 BT',
#  'Bookman Old Style',
#  'Centaur',
#  'Trebuchet MS',
#  'HYGungSo-Bold',
#  'Cambria',
#  'AmeriGarmnd BT',
#  'MoeumT R',
#  'Comic Sans MS',
#  'Wingdings 2',
#  'AmeriGarmnd BT',
#  'Haan YGodic 250',
#  'HYcysM',
#  'Marlett',
#  'Gill Sans MT']
